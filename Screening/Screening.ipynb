# %% [markdown]
# 1. Create a function in python to read the text file and replace specific content
# of the file.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def replace_text(search_text,replace_text):
    """This function will accept a text input to be searched in file and will replace that value with the given new value"""
    # Opening our text file in read only
    try:
        with open(r'E:\INEURON\Screening\example.txt', 'r') as file:
            # Reading the content of the file using the read() function and storing them in a new variable
            data = file.read()
            # Searching and replacing the text using the replace() function
            if data == data.replace(search_text, replace_text):
                return('The Searched Text Not found in file')
            else:
                data = data.replace(search_text, replace_text)
    except Exception as e :
        return ('Exception Occured while Reading the File ' , e)
    try:        
        # Opening our text file in write only mode to write the replaced content
        with open(r'E:\INEURON\Screening\example.txt', 'w+') as file:
            # Writing the replaced data in our text file
            file.write(data)
            return ('The Searched Text replaced with new value in file.')
    except Exception as e :
        return ('Exception Occured while writing to the File ', e)
    

    
file_text=replace_text('placement','screening')
file_text
# Out:
# 'The Searched Text replaced with new value in file.'

# %% [markdown]
# ## 2. Demonstrate use of abstract class, multiple inheritance and decorator in python using examples.

# %% [markdown]
# An abstract class can be considered as a blueprint for other classes. It allows you to create a set of methods that must be created within any child classes built from the abstract class.
#
#  A class which contains one or more abstract methods is called an abstract class. An abstract method is a method that has a declaration but does not have an implementation.

# %%
# Python program showing
# abstract base class work

from abc import ABC, abstractmethod

class Polygon(ABC):
    @abstractmethod
    def noofsides(self):
        pass

class Triangle(Polygon):
    # overriding abstract method
    def noofsides(self):
        print("I have 3 sides")

class Pentagon(Polygon):
    # overriding abstract method
    def noofsides(self):
        print("I have 5 sides")

class Hexagon(Polygon):
    # overriding abstract method
    def noofsides(self):
        print("I have 6 sides")

class Quadrilateral(Polygon):
    # overriding abstract method
    def noofsides(self):
        print("I have 4 sides")

# Driver code
R = Triangle()
R.noofsides()

K = Quadrilateral()
K.noofsides()

R = Pentagon()
R.noofsides()

K = Hexagon()
K.noofsides()
# Out:
# I have 3 sides
# I have 4 sides
# I have 5 sides
# I have 6 sides
